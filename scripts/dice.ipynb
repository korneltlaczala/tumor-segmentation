# %%
import os
import nibabel as nib
import numpy as np
# from sklearn.metrics import f1_score

def dice_score(y_true, y_pred, label):
    y_true_bin = (y_true == label).astype(np.uint8)
    y_pred_bin = (y_pred == label).astype(np.uint8)
    intersection = np.sum(y_true_bin * y_pred_bin)
    return (2. * intersection) / (np.sum(y_true_bin) + np.sum(y_pred_bin) + 1e-8)

def get_id_from_filename(name):
    # Obsłuży np. BraTS2021_00009_seg.nii.gz → 00009
    return name.split("_")[1]

def evaluate(seg_dir, pred_dir):
    labels = [1, 2, 3]
    results = {}

    for seg_name in os.listdir(seg_dir):
        if not seg_name.endswith(".nii.gz"):
            continue

        case_id = get_id_from_filename(seg_name)
        pred_name = f"{case_id}.nii.gz"

        seg_path = os.path.join(seg_dir, seg_name)
        pred_path = os.path.join(pred_dir, pred_name)

        if not os.path.exists(pred_path):
            print(f"Prediction not found for {case_id}")
            continue

        seg_img = nib.load(seg_path).get_fdata()
        pred_img = nib.load(pred_path).get_fdata()
        pred_img = np.copy(pred_img)
        pred_img[pred_img == 4] = 3

        case_result = {}
        for l in labels:
            dice = dice_score(seg_img, pred_img, l)
            case_result[f"Dice_label_{l}"] = dice

        results[case_id] = case_result

    return results

# %%
seg_dir = "../brats_data/BraTS2024-Post/segmentation"
pred_dir = "../brats_data/BraTS2024-Post/output"
results = evaluate(seg_dir, pred_dir)

for case, scores in results.items():
    print(f"{case}:")
    for label, dice in scores.items():
        print(f"  {label}: {dice:.4f}")
# Out:
# Prediction not found for 03064
# Prediction not found for 02795
# Prediction not found for 02822
# Prediction not found for 02790
# Prediction not found for 02911
# Prediction not found for 02820
# Prediction not found for 02985
# Prediction not found for 02972
# Prediction not found for 02948
# Prediction not found for 02901
# Prediction not found for 02781
# Prediction not found for 03026
# Prediction not found for 02813
# Prediction not found for 02871
# Prediction not found for 02810
# Prediction not found for 02954
# Prediction not found for 02940
# Prediction not found for 02856
# Prediction not found for 02857
# Prediction not found for 02957
# Prediction not found for 02806
# Prediction not found for 02897
# Prediction not found for 03015
# Prediction not found for 03013
# Prediction not found for 03025
# Prediction not found for 02865
# Prediction not found for 02923
# Prediction not found for 02782
# Prediction not found for 03027
# Prediction not found for 02890
# Prediction not found for 02873
# Prediction not found for 03060
# Prediction not found for 02961
# Prediction not found for 02939
# Prediction not found for 02950
# Prediction not found for 02869
# Prediction not found for 02780
# Prediction not found for 02904
# Prediction not found for 02818
# Prediction not found for 02801
# Prediction not found for 02831
# Prediction not found for 02829
# Prediction not found for 02929
# Prediction not found for 02851
# Prediction not found for 02886
# Prediction not found for 02900
# Prediction not found for 02932
# Prediction not found for 02933
# Prediction not found for 02982
# Prediction not found for 03049
# Prediction not found for 02788
# Prediction not found for 02916
# Prediction not found for 02980
# Prediction not found for 03019
# Prediction not found for 02917
# Prediction not found for 02854
# Prediction not found for 02968
# Prediction not found for 02835
# Prediction not found for 02965
# Prediction not found for 02952
# Prediction not found for 02834
# Prediction not found for 02959
# Prediction not found for 02984
# Prediction not found for 02928
# Prediction not found for 03051
# Prediction not found for 03031
# Prediction not found for 02899
# Prediction not found for 02898
# Prediction not found for 02799
# Prediction not found for 02866
# Prediction not found for 02877
# Prediction not found for 02809
# Prediction not found for 03061
# Prediction not found for 02988
# Prediction not found for 02849
# Prediction not found for 02828
# Prediction not found for 02907
# Prediction not found for 02805
# Prediction not found for 02876
# Prediction not found for 02791
# Prediction not found for 02934
# Prediction not found for 02955
# Prediction not found for 02847
# Prediction not found for 02872
# Prediction not found for 02981
# Prediction not found for 02983
# Prediction not found for 02778
# Prediction not found for 02843
# Prediction not found for 02930
# Prediction not found for 02842
# Prediction not found for 02989
# Prediction not found for 02868
# 02518:
#   Dice_label_1: 0.9824
#   Dice_label_2: 0.9074
#   Dice_label_3: 0.9523
# 02394:
#   Dice_label_1: 0.0554
#   Dice_label_2: 0.6524
#   Dice_label_3: 0.8010
# 02776:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7448
#   Dice_label_3: 0.0000
# 02136:
#   Dice_label_1: 0.9249
#   Dice_label_2: 0.5923
#   Dice_label_3: 0.9047
# 02144:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8930
#   Dice_label_3: 0.7252
# 02548:
#   Dice_label_1: 0.0659
#   Dice_label_2: 0.7739
#   Dice_label_3: 0.3379
# 02066:
#   Dice_label_1: 0.8401
#   Dice_label_2: 0.9648
#   Dice_label_3: 0.9315
# 02243:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9161
#   Dice_label_3: 0.8950
# 00512:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7139
#   Dice_label_3: 0.0000
# 02336:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8803
#   Dice_label_3: 0.6436
# 02132:
#   Dice_label_1: 0.8921
#   Dice_label_2: 0.9765
#   Dice_label_3: 0.9189
# 02340:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8898
#   Dice_label_3: 0.0000
# 02709:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 02074:
#   Dice_label_1: 0.1821
#   Dice_label_2: 0.9241
#   Dice_label_3: 0.9483
# 02763:
#   Dice_label_1: 0.0360
#   Dice_label_2: 0.9551
#   Dice_label_3: 0.8833
# 02662:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.1125
#   Dice_label_3: 0.0000
# 02602:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8205
#   Dice_label_3: 0.7675
# 02246:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9358
#   Dice_label_3: 0.0000
# 02758:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8424
#   Dice_label_3: 0.0000
# 02685:
#   Dice_label_1: 0.0619
#   Dice_label_2: 0.8589
#   Dice_label_3: 0.7670
# 02720:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7364
#   Dice_label_3: 0.0000
# 02372:
#   Dice_label_1: 0.3582
#   Dice_label_2: 0.9378
#   Dice_label_3: 0.9194
# 02635:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9526
#   Dice_label_3: 0.0000
# 02112:
#   Dice_label_1: 0.3320
#   Dice_label_2: 0.9543
#   Dice_label_3: 0.8809
# 00511:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 02236:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 02337:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7341
#   Dice_label_3: 0.0000
# 02334:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8897
#   Dice_label_3: 0.0000
# 02651:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7123
#   Dice_label_3: 0.0439
# 02609:
#   Dice_label_1: 0.6331
#   Dice_label_2: 0.6496
#   Dice_label_3: 0.9160
# 02665:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8220
#   Dice_label_3: 0.0000
# 02378:
#   Dice_label_1: 0.3566
#   Dice_label_2: 0.9409
#   Dice_label_3: 0.9482
# 02770:
#   Dice_label_1: 0.7251
#   Dice_label_2: 0.8420
#   Dice_label_3: 0.8231
# 02775:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.1980
#   Dice_label_3: 0.6223
# 02759:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 02219:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.5389
#   Dice_label_3: 0.0000
# 02167:
#   Dice_label_1: 0.0006
#   Dice_label_2: 0.8506
#   Dice_label_3: 0.8092
# 02093:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8448
#   Dice_label_3: 0.0000
# 02256:
#   Dice_label_1: 0.1684
#   Dice_label_2: 0.6405
#   Dice_label_3: 0.8818
# 02748:
#   Dice_label_1: 0.9700
#   Dice_label_2: 0.7757
#   Dice_label_3: 0.9711
# 02368:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.6042
#   Dice_label_3: 0.8158
# 00063:
#   Dice_label_1: 0.7222
#   Dice_label_2: 0.8428
#   Dice_label_3: 0.7109
# 02118:
#   Dice_label_1: 0.8165
#   Dice_label_2: 0.9347
#   Dice_label_3: 0.9676
# 02598:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9465
#   Dice_label_3: 0.4702
# 02091:
#   Dice_label_1: 0.5599
#   Dice_label_2: 0.8604
#   Dice_label_3: 0.4687
# 02514:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8432
#   Dice_label_3: 0.2237
# 02661:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 02663:
#   Dice_label_1: 0.8172
#   Dice_label_2: 0.8562
#   Dice_label_3: 0.8762
# 02227:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8991
#   Dice_label_3: 0.0000
# 00557:
#   Dice_label_1: 0.7810
#   Dice_label_2: 0.9401
#   Dice_label_3: 0.9299
# 02343:
#   Dice_label_1: 0.8922
#   Dice_label_2: 0.5971
#   Dice_label_3: 0.8854
# 02721:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8805
#   Dice_label_3: 0.0000
# 00533:
#   Dice_label_1: 0.2030
#   Dice_label_2: 0.6316
#   Dice_label_3: 0.6740
# 02657:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 00033:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.2294
#   Dice_label_3: 0.0000
# 02149:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7341
#   Dice_label_3: 0.0000
# 02230:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9242
#   Dice_label_3: 0.0000
# 02652:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8662
#   Dice_label_3: 0.0000
# 02207:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8928
#   Dice_label_3: 0.0000
# 02556:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8987
#   Dice_label_3: 0.0000
# 02735:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8232
#   Dice_label_3: 0.0000
# 00008:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.6343
#   Dice_label_3: 0.0000
# 02237:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8895
#   Dice_label_3: 0.0000
# 02718:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7657
#   Dice_label_3: 0.0000
# 02777:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8155
#   Dice_label_3: 0.5736
# 02268:
#   Dice_label_1: 0.4741
#   Dice_label_2: 0.7955
#   Dice_label_3: 0.7944
# 00518:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8521
#   Dice_label_3: 0.7670
# 02708:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7595
#   Dice_label_3: 0.0000
# 02625:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 02648:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7985
#   Dice_label_3: 0.0000
# 02756:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.2981
#   Dice_label_3: 0.5883
# 02239:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8329
#   Dice_label_3: 0.0000
# 02760:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8668
#   Dice_label_3: 0.8065
# 02223:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8249
#   Dice_label_3: 0.0000
# 00472:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0684
#   Dice_label_3: 0.0000
# 02157:
#   Dice_label_1: 0.8093
#   Dice_label_2: 0.9687
#   Dice_label_3: 0.9003
# 02063:
#   Dice_label_1: 0.0432
#   Dice_label_2: 0.9749
#   Dice_label_3: 0.9462
# 02220:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.5632
#   Dice_label_3: 0.0000
# 00528:
#   Dice_label_1: 0.8296
#   Dice_label_2: 0.8619
#   Dice_label_3: 0.9239
# 02666:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7064
#   Dice_label_3: 0.0000
# 02654:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.6700
#   Dice_label_3: 0.0000
# 02751:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 02753:
#   Dice_label_1: 0.3496
#   Dice_label_2: 0.8672
#   Dice_label_3: 0.6915
# 02707:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9096
#   Dice_label_3: 0.0000
# 02335:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9447
#   Dice_label_3: 0.7543
# 02637:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7753
#   Dice_label_3: 0.8097
# 02725:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.5666
#   Dice_label_3: 0.0000
# 02208:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.0000
#   Dice_label_3: 0.0000
# 02247:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.3791
#   Dice_label_3: 0.0000
# 02238:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8763
#   Dice_label_3: 0.0000
# 02774:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.5698
#   Dice_label_3: 0.1344
# 02771:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.4486
#   Dice_label_3: 0.0000
# 02717:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.7589
#   Dice_label_3: 0.0000
# 02344:
#   Dice_label_1: 0.8670
#   Dice_label_2: 0.7538
#   Dice_label_3: 0.9430
# 02769:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.4387
#   Dice_label_3: 0.0000
# 02631:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.5840
#   Dice_label_3: 0.0000
# 02605:
#   Dice_label_1: 0.0001
#   Dice_label_2: 0.6767
#   Dice_label_3: 0.3413
# 02727:
#   Dice_label_1: 0.7489
#   Dice_label_2: 0.9415
#   Dice_label_3: 0.9188
# 02740:
#   Dice_label_1: 0.9626
#   Dice_label_2: 0.6367
#   Dice_label_3: 0.9432
# 02228:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9456
#   Dice_label_3: 0.0000
# 02211:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.4198
#   Dice_label_3: 0.0000
# 02649:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8504
#   Dice_label_3: 0.2426
# 02176:
#   Dice_label_1: 0.0021
#   Dice_label_2: 0.9418
#   Dice_label_3: 0.4076
# 02698:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.3916
#   Dice_label_3: 0.0000
# 00543:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8251
#   Dice_label_3: 0.0000
# 02339:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.8813
#   Dice_label_3: 0.8327
# 02693:
#   Dice_label_1: 0.0000
#   Dice_label_2: 0.9588
#   Dice_label_3: 0.0000
# 00485:
#   Dice_label_1: 0.9002
#   Dice_label_2: 0.8269
#   Dice_label_3: 0.8767

# %%
seg_dir = "BraTS2025Pre/segmentation"
pred_dir = "BraTS2025Pre/output"
results = evaluate(seg_dir, pred_dir)

for case, scores in results.items():
    print(f"{case}:")
    for label, dice in scores.items():
        print(f"  {label}: {dice:.4f}")
# Out:
# 00088:
#   Dice_label_1: 0.9665
#   Dice_label_2: 0.9458
#   Dice_label_3: 0.0000
# 00320:
#   Dice_label_1: 0.5557
#   Dice_label_2: 0.8306
#   Dice_label_3: 0.0000
# 00577:
#   Dice_label_1: 0.9687
#   Dice_label_2: 0.9558
#   Dice_label_3: 0.0000
# 00624:
#   Dice_label_1: 0.9693
#   Dice_label_2: 0.8603
#   Dice_label_3: 0.0000
# 00704:
#   Dice_label_1: 0.9879
#   Dice_label_2: 0.8408
#   Dice_label_3: 0.0000
# 00714:
#   Dice_label_1: 0.9864
#   Dice_label_2: 0.9823
#   Dice_label_3: 0.0000
# 00772:
#   Dice_label_1: 0.9848
#   Dice_label_2: 0.6948
#   Dice_label_3: 0.0000
# 00816:
#   Dice_label_1: 0.9731
#   Dice_label_2: 0.9865
#   Dice_label_3: 0.0000
# 01005:
#   Dice_label_1: 0.9146
#   Dice_label_2: 0.9217
#   Dice_label_3: 0.0000
# 01116:
#   Dice_label_1: 0.9716
#   Dice_label_2: 0.6603
#   Dice_label_3: 0.0000
# 01250:
#   Dice_label_1: 0.8937
#   Dice_label_2: 0.9215
#   Dice_label_3: 0.0000
# 01498:
#   Dice_label_1: 0.7601
#   Dice_label_2: 0.8592
#   Dice_label_3: 0.0000
